# %%
import pandas as pd
df = pd.read_csv('P05-01.csv')

# %%
# Subsoal 1

len(df.loc[(df['Attrition_Flag'] == 'Attrited Customer') & (df['Gender'] == 'F')])
# Out:
# 930

# %%
# Subsoal 2

imax = df["Total_Revolving_Bal"].max()
df.loc[df['Total_Revolving_Bal'] == imax]
# Out:
#        CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 3      769911858  Existing Customer            40      F                4
# 8      710930508  Existing Customer            37      M                3
# 18     806160108  Existing Customer            61      M                1
# 32     709029408  Existing Customer            41      M                4
# 42     773146383  Existing Customer            50      F                1
# ...          ...                ...           ...    ...              ...
# 10071  713281833  Attrited Customer            37      M                3
# 10078  709398708  Existing Customer            40      M                3
# 10079  715090008  Existing Customer            45      M                4
# 10113  713733633  Attrited Customer            27      M                0
# 10119  716893683  Attrited Customer            55      F                3
#
#       Education_Level Marital_Status Income_Category Card_Category  \
# ...

# %%
# Subsoal 3
len(df.loc[(df['Education_Level'] == 'High School') & (df['Marital_Status'] == 'Married')])
# Out:
# 949

# %%
# Subsoal 4

df[df['Total_Trans_Ct'] >= 100]['Card_Category'].value_counts()
# Out:
# Card_Category
# Blue        526
# Silver      121
# Gold         32
# Platinum      8
# Name: count, dtype: int64

# %%
# Subsoal 5

df[df['Income_Category'] == '$80K - $120K'].sort_values('Customer_Age')[:5]['CLIENTNUM']
# Out:
# 9295    719324658
# 766     787456608
# 9494    710262408
# 1381    720497958
# 1677    780374133
# Name: CLIENTNUM, dtype: int64
